# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
## To Import Fill
df = pd.read_csv("melb_data.csv")
df.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
# ...

# %%
## For Last Five Data
df.tail()
# Out:
#        Unnamed: 0        Suburb          Address  Rooms Type      Price  \
# 18391       23540  Williamstown  8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown     96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie     17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville       6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville    33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 18391     SP        Greg  26/08/2017       6.8  ...       2.0  1.0       NaN
# 18392     PI     Sweeney  26/08/2017       6.8  ...       1.0  5.0     866.0
# 18393      S  Buckingham  26/08/2017      12.7  ...       3.0  2.0       NaN
# 18394     SP     Village  26/08/2017       6.3  ...       1.0  1.0     362.0
# 18395     VB     Village  26/08/2017       6.3  ...       2.0  2.0       NaN
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Address        18396 non-null  object
#  3   Rooms          18396 non-null  int64
#  4   Type           18396 non-null  object
#  5   Price          18396 non-null  float64
#  6   Method         18396 non-null  object
#  7   SellerG        18396 non-null  object
#  8   Date           18396 non-null  object
#  9   Distance       18395 non-null  float64
#  10  Postcode       18395 non-null  float64
#  11  Bedroom2       14927 non-null  float64
#  12  Bathroom       14925 non-null  float64
#  13  Car            14820 non-null  float64
#  14  Landsize       13603 non-null  float64
#  15  BuildingArea   7762 non-null   float64
#  16  YearBuilt      8958 non-null   float64
# ...

# %% [markdown]
# Missing Value Treatmeant Using SKlearn

# %%
# from sklearn.impute import KNNImputer
# Impute=KNNImputer()

# for i in df.select_dtypes(include="number").columns:
#   df[i]=Impute.fit_transform(df[[i]])

# %%
#df

# %%
## To Finding Missing Values
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          3469
# Bathroom          3471
# Car               3576
# Landsize          4793
# BuildingArea     10634
# YearBuilt         9438
# CouncilArea       6163
# Lattitude         3332
# Longtitude        3332
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
## To Finding Same Data Using Multipple Time
print(df.duplicated().sum())
# Out:
# 0

# %%
## Finding Mean Value
df["YearBuilt"].mean()
# Out:
# np.float64(1965.8799955347176)

# %%
## Filling Missing Values BY Mean
df["YearBuilt"].fillna(df["YearBuilt"].mean(),inplace = True)
# Out:
# /tmp/ipykernel_2037/3390096840.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["YearBuilt"].fillna(df["YearBuilt"].mean(),inplace = True)

# %%
df["BuildingArea"].mean()
# Out:
# np.float64(151.22021949239888)

# %%
df["BuildingArea"].fillna(df["BuildingArea"].mean(),inplace = True)
# Out:
# /tmp/ipykernel_2037/4246735309.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BuildingArea"].fillna(df["BuildingArea"].mean(),inplace = True)

# %%
df["CouncilArea"].fillna("BBC",inplace = True)
# Out:
# /tmp/ipykernel_2037/3670922783.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CouncilArea"].fillna("BBC",inplace = True)

# %%
df["Car"].mean()
# Out:
# np.float64(1.6155195681511472)

# %%
df["Car"].fillna(df["Car"].mean(),inplace = True)
# Out:
# /tmp/ipykernel_2037/3053455944.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Car"].fillna(df["Car"].mean(),inplace = True)

# %%
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=30)
sns.barplot(x="Regionname",y="Landsize",data=df,color="Green",edgecolor="Black")
plt.title("Regionname vs Landsize")
plt.xlabel("Regionname")
plt.ylabel("Landsize")
plt.show()

# %%
df1 = df.drop(["Suburb","Address","Date","Car","Propertycount","Type","Method","SellerG","Regionname","CouncilArea"],axis="columns")
df1.head()
# Out:
#    Unnamed: 0  Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  \
# 0           1      2  1480000.0       2.5    3067.0       2.0       1.0
# 1           2      2  1035000.0       2.5    3067.0       2.0       1.0
# 2           4      3  1465000.0       2.5    3067.0       3.0       2.0
# 3           5      3   850000.0       2.5    3067.0       3.0       2.0
# 4           6      4  1600000.0       2.5    3067.0       3.0       1.0
#
#    Landsize  BuildingArea    YearBuilt  Lattitude  Longtitude
# 0     202.0    151.220219  1965.879996   -37.7996    144.9984
# 1     156.0     79.000000  1900.000000   -37.8079    144.9934
# 2     134.0    150.000000  1900.000000   -37.8093    144.9944
# 3      94.0    151.220219  1965.879996   -37.7969    144.9969
# 4     120.0    142.000000  2014.000000   -37.8072    144.9941

# %%
# df1 = df.drop(["Suburb","Address","Date","Landsize","Distance","Car","Postcode","Propertycount","Longtitude","Type","Method","SellerG","Regionname","CouncilArea","Lattitude","YearBuilt"],axis="columns")
# df1.head()

# %%
df1.shape
# Out:
# (18396, 12)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0         0
# Rooms              0
# Price              0
# Distance           1
# Postcode           1
# Bedroom2        3469
# Bathroom        3471
# Landsize        4793
# BuildingArea       0
# YearBuilt          0
# Lattitude       3332
# Longtitude      3332
# dtype: int64

# %%
for col in df1.select_dtypes(include=['number']).columns:
    if df1[col].isnull().any():
        df1[col].fillna(df1[col].mean(), inplace=True)
# Out:
# /tmp/ipykernel_2037/2150218719.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1[col].fillna(df1[col].mean(), inplace=True)

# %% [markdown]
# Now, let's check the missing values again to confirm they have been filled:

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# Rooms           0
# Price           0
# Distance        0
# Postcode        0
# Bedroom2        0
# Bathroom        0
# Landsize        0
# BuildingArea    0
# YearBuilt       0
# Lattitude       0
# Longtitude      0
# dtype: int64

# %%
## Group By
grouped_by = df.groupby("Landsize")
grouped_count = grouped_by["Landsize"].count()
grouped_count
# Out:
# Landsize
# 0.0         1942
# 1.0            2
# 2.0            1
# 3.0            1
# 5.0            1
#             ...
# 41400.0        1
# 44500.0        1
# 75100.0        1
# 76000.0        1
# 433014.0       1
# Name: Landsize, Length: 1449, dtype: int64

# %%
reg_lan = df.groupby(["Regionname","Landsize"])["Postcode"].count()
reg_lan
# Out:
# Regionname            Landsize
# Eastern Metropolitan  0.0         46
#                       1.0          1
#                       29.0         1
#                       55.0         1
#                       65.0         1
#                                   ..
# Western Victoria      766.0        1
#                       800.0        1
#                       900.0        1
#                       1241.0       1
#                       1670.0       1
# Name: Postcode, Length: 3990, dtype: int64

# %% [markdown]
# Data Visualization

# %%
for i in df.select_dtypes(include="number").columns:
  sns.histplot(x=i,data=df)
  plt.show()

# %%
sns.scatterplot(x="Rooms",y="Price",data=df1)
# Out:
# <Axes: xlabel='Rooms', ylabel='Price'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(x="Rooms",y="Price",data=df1,color="darkblue")
plt.title("Rooms vs Price")
plt.xlabel("Rooms")
plt.ylabel("Price")
plt.show()

# %%
X = df1.drop("Price",axis="columns")
X.head()
# Out:
#    Unnamed: 0  Rooms  Distance  Postcode  Bedroom2  Bathroom  Landsize  \
# 0           1      2       2.5    3067.0       2.0       1.0     202.0
# 1           2      2       2.5    3067.0       2.0       1.0     156.0
# 2           4      3       2.5    3067.0       3.0       2.0     134.0
# 3           5      3       2.5    3067.0       3.0       2.0      94.0
# 4           6      4       2.5    3067.0       3.0       1.0     120.0
#
#    BuildingArea    YearBuilt  Lattitude  Longtitude
# 0    151.220219  1965.879996   -37.7996    144.9984
# 1     79.000000  1900.000000   -37.8079    144.9934
# 2    150.000000  1900.000000   -37.8093    144.9944
# 3    151.220219  1965.879996   -37.7969    144.9969
# 4    142.000000  2014.000000   -37.8072    144.9941

# %%
X.head()
# Out:
#    Unnamed: 0  Rooms  Distance  Postcode  Bedroom2  Bathroom  Landsize  \
# 0           1      2       2.5    3067.0       2.0       1.0     202.0
# 1           2      2       2.5    3067.0       2.0       1.0     156.0
# 2           4      3       2.5    3067.0       3.0       2.0     134.0
# 3           5      3       2.5    3067.0       3.0       2.0      94.0
# 4           6      4       2.5    3067.0       3.0       1.0     120.0
#
#    BuildingArea    YearBuilt  Lattitude  Longtitude
# 0    151.220219  1965.879996   -37.7996    144.9984
# 1     79.000000  1900.000000   -37.8079    144.9934
# 2    150.000000  1900.000000   -37.8093    144.9944
# 3    151.220219  1965.879996   -37.7969    144.9969
# 4    142.000000  2014.000000   -37.8072    144.9941

# %%
y = df1.Price
y.head()
# Out:
# 0    1480000.0
# 1    1035000.0
# 2    1465000.0
# 3     850000.0
# 4    1600000.0
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression



model = LinearRegression()

model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.46293921114201486

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
cross_val_score(LinearRegression(),X,y,cv=cv)
# Out:
# array([ 0.48065609,  0.46814039,  0.47243258, -1.00731985, -2.03598355])

# %%
## Advanced
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
  algos = {
      'linear_regression' : {
          'model': LinearRegression(),
          'params': {
          }
      },
      'lasso' : {
          'model': Lasso(),
          'params': {
              'alpha': [1,2],
              'selection': ['random', 'cyclic']
          }
      },
      'decision_tree': {
          'model': DecisionTreeRegressor(),
          'params': {
              'criterion' : ['friedman_mse', 'squared_error', 'poisson'],
              'splitter': ['best','random']
          }
      }
  }
  scores = []
  cv = ShuffleSplit(n_splits=5, test_size=0.2,random_state=0)
  for algo_name, config in algos.items():
    gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
    gs.fit(X,y)
    scores.append({
        'model': algo_name,
        'best_score': gs.best_score_,
        'best_params': gs.best_params_
    })

  return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
#                model  best_score  \
# 0  linear_regression   -0.324415
# 1              lasso   -0.324432
# 2      decision_tree    0.506315
#
#                                          best_params
# 0                                                 {}
# 1                {'alpha': 1, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'Rooms', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude'],
#       dtype='object')

# %%
def predict_price(Rooms,Landsize,Distance,Postcode,Bedroom2,Bathroom,BuildingArea,YearBuilt,Lattitude,Longtitude):

  x = np.zeros(len(X.columns))

  x[0] = Rooms
  x[1] = Landsize
  x[2] = Distance
  x[3] = Postcode
  x[4] = Bedroom2
  x[5] = Bathroom
  x[6] = BuildingArea
  x[7] = YearBuilt
  x[8] = Lattitude
  x[9] = Longtitude
  if model.predict([x])[0] >= 0:
    x[8] = Lattitude * -1
  return model.predict([x])[0]
  #return max(model.predict([x])[0],0)

# %%
import warnings
warnings.filterwarnings("ignore")
predict_price(2,345,3.4,342,3,2,345,2342.33,34,456)
# Out:
# np.float64(-562267128.67085)

# %%
# import pickle
# with open('melb_data.pickle','wb') as f:
#   pickle.dump(model,f)

# %%
# import json
# columns = {
#     'data_columns' : [col.lower() for col in X.columns]
# }
# with open("columns.json","w") as f:
#   f.write(json.dumps(columns))

# %%
import joblib
joblib.dump(model,"melb_data.pkl")
# Out:
# ['melb_data.pkl']
